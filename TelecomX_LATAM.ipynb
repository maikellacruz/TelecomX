# %% [markdown]
# <a href="https://colab.research.google.com/github/maikellacruz/TelecomX/blob/main/TelecomX_LATAM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #📌 Extracción

# %%
import json

# Ruta del archivo
ruta = '/content/TelecomX_Data.json'

# Abrir y cargar los datos
with open(ruta, 'r') as f:
    data = json.load(f)

# Ver los primeros elementos (si es una lista)
print(data[:2])  # O usa print(data) si es un diccionario
# Out:
# [{'customerID': '0002-ORFBO', 'Churn': 'No', 'customer': {'gender': 'Female', 'SeniorCitizen': 0, 'Partner': 'Yes', 'Dependents': 'Yes', 'tenure': 9}, 'phone': {'PhoneService': 'Yes', 'MultipleLines': 'No'}, 'internet': {'InternetService': 'DSL', 'OnlineSecurity': 'No', 'OnlineBackup': 'Yes', 'DeviceProtection': 'No', 'TechSupport': 'Yes', 'StreamingTV': 'Yes', 'StreamingMovies': 'No'}, 'account': {'Contract': 'One year', 'PaperlessBilling': 'Yes', 'PaymentMethod': 'Mailed check', 'Charges': {'Monthly': 65.6, 'Total': '593.3'}}}, {'customerID': '0003-MKNFE', 'Churn': 'No', 'customer': {'gender': 'Male', 'SeniorCitizen': 0, 'Partner': 'No', 'Dependents': 'No', 'tenure': 9}, 'phone': {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}, 'internet': {'InternetService': 'DSL', 'OnlineSecurity': 'No', 'OnlineBackup': 'No', 'DeviceProtection': 'No', 'TechSupport': 'No', 'StreamingTV': 'No', 'StreamingMovies': 'Yes'}, 'account': {'Contract': 'Month-to-month', 'PaperlessBilling': 'No', 'PaymentMe
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   facturacion_mensual  7 non-null      int64
#  1   dias_del_mes         7 non-null      int64
#  2   edad_cliente         7 non-null      int64
# dtypes: int64(3)
# memory usage: 300.0 bytes

# %%
df.isnull().sum()
# Out:
# facturacion_mensual    0
# dias_del_mes           0
# edad_cliente           0
# dtype: int64

# %%
import pandas as pd

df = pd.DataFrame(data)

# Mostrar las primeras filas
df.head()
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %%
print(df.columns)
# Out:
# Index(['customerID', 'Churn', 'customer', 'phone', 'internet', 'account'], dtype='object')

# %%
df.columns = df.columns.str.strip()  # Elimina espacios extra alrededor de los nombres

# %%
print(df.columns)  # Revisa las columnas disponibles
# Out:
# Index(['customerID', 'Churn', 'customer', 'phone', 'internet', 'account'], dtype='object')

# %%
df.columns = df.columns.str.strip()  # Eliminar espacios extra

# %%
# Análisis descriptivo de las columnas numéricas
df.describe()
# Out:
#         customerID Churn                                           customer  \
# count         7267  7267                                               7267
# unique        7267     3                                                891
# top     9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# freq             1  5174                                                223
#
#                                                  phone  \
# count                                             7267
# unique                                               3
# top     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# freq                                              3495
#
#                                                  internet  \
# count                                                7267
# unique                                                129
# top     {'InternetService': 'No', 'OnlineSecurity': 'N...
# freq                                                 1581
#
# ...

# %% [markdown]
# #🔧 Transformación

# %%
df.columns = df.columns.str.strip()

# %%
df['facturacion_mensual'] = 0  # Asigna 0 a toda la columna

# %%
df['Cuentas_Diarias'] = 0  # Asigna 0 a toda la columna 'Cuentas_Diarias'

# %%
import pandas as pd

# Supón que tienes un DataFrame como este (solo de ejemplo):
df = pd.DataFrame({
    'facturacion_mensual': [3000, 4500, 6000, 7500, 5000],  # Facturación mensual
    'dias_del_mes': [30, 30, 31, 31, 30]  # Días del mes (puedes adaptarlo si tienes esta columna)
})

# Crear la columna 'Cuentas_Diarias' dividiendo la 'facturacion_mensual' entre 'dias_del_mes'
df['Cuentas_Diarias'] = df['facturacion_mensual'] / df['dias_del_mes']

# Mostrar el DataFrame resultante
print(df)
# Out:
#    facturacion_mensual  dias_del_mes  Cuentas_Diarias
# 0                 3000            30       100.000000
# 1                 4500            30       150.000000
# 2                 6000            31       193.548387
# 3                 7500            31       241.935484
# 4                 5000            30       166.666667

# %%
df['Cuentas_Diarias'] = df['facturacion_mensual'] / 30  # Asumir 30 días por mes

# %%
print(df.columns)
# Out:
# Index(['facturacion_mensual', 'dias_del_mes', 'Cuentas_Diarias'], dtype='object')

# %%
df.rename(columns={'nombre_incorrecto': 'columna_textual'}, inplace=True)

# %%
# Eliminar espacios en los nombres de las columnas
df.columns = df.columns.str.strip()

# %%
# Renombrar la columna si es necesario
df.rename(columns={'nombre_incorrecto': 'respuesta'}, inplace=True)

# %%
import pandas as pd

# Suponiendo que tu DataFrame se llama df

# Realizar un análisis descriptivo básico
descripcion = df.describe()

# Mostrar las métricas generales
print(descripcion)

# Cálculo adicional de asimetría y curtosis
asimetria = df.skew()
curtosis = df.kurt()

# Mostrar asimetría y curtosis
print("\nAsimetría de las columnas numéricas:")
print(asimetria)

print("\nCurtosis de las columnas numéricas:")
print(curtosis)
# Out:
#        facturacion_mensual  dias_del_mes  Cuentas_Diarias
# count             5.000000      5.000000         5.000000
# mean           5200.000000     30.400000       173.333333
# std            1680.773631      0.547723        56.025788
# min            3000.000000     30.000000       100.000000
# 25%            4500.000000     30.000000       150.000000
# 50%            5000.000000     30.000000       166.666667
# 75%            6000.000000     31.000000       200.000000
# max            7500.000000     31.000000       250.000000
#
# Asimetría de las columnas numéricas:
# facturacion_mensual    0.147425
# dias_del_mes           0.608581
# Cuentas_Diarias        0.147425
# dtype: float64
#
# Curtosis de las columnas numéricas:
# facturacion_mensual    0.154280
# dias_del_mes          -3.333333
# Cuentas_Diarias        0.154280
# dtype: float64

# %%
import pandas as pd

# Crear un DataFrame de ejemplo con los datos correctos
data = {
    'facturacion_mensual': [3000, 4500, 5000, 7000, 10000, 6000, 4000],
    'dias_del_mes': [30, 30, 31, 30, 31, 30, 31],
    'edad_cliente': [25, 30, 35, 40, 45, 50, 55]
}

# Crear el DataFrame
df = pd.DataFrame(data)

# Realizar el análisis descriptivo
descripcion = df.describe()

# Mostrar las métricas generales
print(descripcion)

# Cálculo adicional de asimetría y curtosis
asimetria = df.skew()
curtosis = df.kurt()

# Mostrar asimetría y curtosis
print("\nAsimetría de las columnas numéricas:")
print(asimetria)

print("\nCurtosis de las columnas numéricas:")
print(curtosis)
# Out:
#        facturacion_mensual  dias_del_mes  edad_cliente
# count             7.000000      7.000000      7.000000
# mean           5642.857143     30.428571     40.000000
# std            2322.252601      0.534522     10.801234
# min            3000.000000     30.000000     25.000000
# 25%            4250.000000     30.000000     32.500000
# 50%            5000.000000     30.000000     40.000000
# 75%            6500.000000     31.000000     47.500000
# max           10000.000000     31.000000     55.000000
#
# Asimetría de las columnas numéricas:
# facturacion_mensual    1.129299
# dias_del_mes           0.374166
# edad_cliente           0.000000
# dtype: float64
#
# Curtosis de las columnas numéricas:
# facturacion_mensual    1.367826
# dias_del_mes          -2.800000
# edad_cliente          -1.200000
# dtype: float64

# %%
print(df.head())
# Out:
#    facturacion_mensual  dias_del_mes  edad_cliente
# 0                 3000            30            25
# 1                 4500            30            30
# 2                 5000            31            35
# 3                 7000            30            40
# 4                10000            31            45

# %% [markdown]
# #📊 Carga y análisis

# %% [markdown]
# #📄Informe final
